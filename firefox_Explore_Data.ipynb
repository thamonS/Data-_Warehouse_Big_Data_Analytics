# %% [markdown]
# <a href="https://colab.research.google.com/github/thamonS/Data-_Warehouse_Big_Data_Analytics/blob/main/firefox_Explore_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini Project 2: Data Analytics and Modeling

# %% [markdown]
# <img src="https://datarundown.com/wp-content/uploads/2023/05/Model-Data-Analytics.jpg" width="400px">

# %% [markdown]
# ชื่อกลุ่ม: firefox
#
# รายชื่อสมาชิก การแบ่งงาน และสัดส่วนในการทำงาน:
# 1. นายรัชชานนท์ พันกาฬสินธุ์
# 2. นางสาวพรวลัย ฟ็อกซ์ออล
# 3. นางสาวธมน ศิริพราหมณกุล
#
# กำหนดส่ง: พุธ 9 ตุลาคม 2567
#
# รายงานในชั้นเรียน: พฤหัสบดี 10 ตุลาคม 2567
#
# ** NOTE **
# * อย่าลืมบันทึกงานที่ทำในโน้ตบุ๊คนี้เป็นประจำขณะทำงาน มิเช่นนั้นงานที่ทำอยู่อาจสูญหายได้
# * **เริ่มทำแต่เนิ่น ๆ อย่ารอที่จะทำก่อนส่ง เพราะจะทำไม่เสร็จ เนื่องจากปัญหามากมายที่จะเกิดขึ้นระหว่างการทำงาน และอาจารย์ไม่รับปรึกษาในคืนก่อนส่ง**
# ----------------------

# %% [markdown]
# ### เลือกชุดข้อมูล 1 ชุดจากข้อมูลที่กำหนดให้ต่อไปนี้
# * <b>MovieLens 1M Data Set<b>
#     * ข้อมูลชุดนี้มีข้อมูลเกี่ยวกับ movies, users, และ how they rate the movies
#     * สามารถดูรายละเอียดได้ที่ http://grouplens.org/datasets/movielens/
#     * Download the 1 million ratings data set from https://grouplens.org/datasets/movielens/1m/
#     * Merge all of the data into a single Pandas DataFrame. See
#         * https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
#
# * <b>Walmart_Sales_Forecast<b>
#     * สามารถดูรายละเอียดได้ที่ https://github.com/Asikpalysik/Walmart_Sales_Forecast/tree/main
#     * ข้อมูลประกอบด้วยไฟล์ features.csv, stores.csv และ ข้อมูลยอดขาย (train.csv และ test.csv)
#     * ให้ใช้ข้อมูลจากทุกไฟล์ทุกอย่างประกอบกันในการวิเคราะห์
#
# * <b>NYC Taxi Trips<b>
#     * ข้อมูลทริปของแท็กซี่ในเมืองนิวยอร์กจาก https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#     * ข้อมูลเก็บโดย The NYC Taxi and Limousine Commission (TLC) ประกอบด้วย pick-up and drop-off dates/times, pick-up and drop-off locations, trip distances, itemized fares, rate types, payment types, and driver-reported passenger counts
#     * นอกจากไฟล์ข้อมูลทริปของแท็กซี่แล้ว ยังมีข้อมูลเกี่ยวกับ zone ของพื้นที่ที่ให้บริการ และคำอธิบายข้อมูลในส่วนล่างสุดของหน้าเดียวกัน
#     * ให้ศึกษาข้อมูลการเดินทางของแท็กซี่เหลืองหรือแท็กซี่เขียวในช่วงหนึ่ง (เช่น 1 เดือน หรือ 1 ปีที่ผ่านมา เป็นต้น)
#     * ตัวอย่างการอ่านไฟล์ parquet
#     ```python
#     # install this module to read .parquet files
#     !pip install pyarrow
#     import pyarrow.parquet as pq
#     trips = pq.read_table('yellow_tripdata_2023-09.parquet')
#     trips = trips.to_pandas()
#     trips
#     ```
#
# ----------------------------------

# %% [markdown]
# ### ศึกษาข้อมูลที่เลือกใช้ แล้วทำการ
# * Tell story about data อธิบายลักษณะของข้อมูล ทำความเข้าใจเกี่ยวกับข้อมูลชุดนี้ ด้วยสถิติ และนำเสนอด้วยแผนภาพ แผนภูมิ หรือกราฟต่าง ๆ
# * ตั้ง<span style="color:red">*ปัญหาหรือคำถามเชิงองค์กรหรือธุรกิจ*</span>ที่กลุ่มท่านสนใจเกี่ยวกับข้อมูลนี้ แล้วทำการคาดการณ์ (conjectures) เกี่ยวกับ<span style="color:red">*ปัญหาหรือคำถาม*</span>ที่ได้ตั้งไว้อย่างน้อย 3 ข้อ แล้วสนับสนุนหรือปฏิเสธข้อคาดการณ์ด้วยการวิเคราะห์ข้อมูลหรือด้วย data visualization
#     * ปัญหาที่สนใจมีความสำคัญอย่างไร?
#     * ข้อคาดการณ์ของท่านจะนำไปสู่การแก้ไขปัญหาหรือตอบคำถามอย่างไร?
# * สร้างตัวแบบทำนายโดยใช้ข้อมูลที่เลือกในการตอบปัญหาหรือคำถาม
#     - prepare data
#     - feature engineering
#     - partition data (train/test, consider class if any)
#     - handle imbalance data (over sampling, sub sampling)
#     - build model
#      - hyperparameter tuning
#     - test model
#     - ทำหลาย ๆ model เพื่อเปรียบเทียบว่า model ไหนดีที่สุด

# %% [markdown]
# #### ปัญหา/คำถามที่สนใจคืออะไร
# 1. มีปัจจัยใดบ้างที่ส่งผลต่อการให้ทิปของลูกค้า
# 2. ปัจจัยด้านสภาพอากาศใดบ้างที่ส่งผลต่อการใช้บริการแท็กซี่ในแต่ละฤดู
# 3. ความแตกต่างในการใช้บริการแท็กซี่ระหว่างฤดูหนาวและฤดูร้อน
# 4. การเดินทางของผู้โดยสารในวันธรรมดาและวันหยุดสุดสัปดาห์แตกต่างกันอย่างไร
# 5. โซนใดในพื้นที่ให้บริการแท็กซี่ที่มีผู้โดยสารให้ทิปสูงที่สุด
#
#
# #### ปัญหา/คำถามที่สนใจมีความสำคัญอย่างไร?
# ช่วยให้สามารถปรับปรุงการให้บริการแท็กซี่ได้อย่างเหมาะสม ซึ่งเป็นส่วนช่วยเพิ่มรายได้ ลดต้นทุน และสร้างประสบการณ์ที่ดีให้กับลูกค้า
# นอกจากนี้ยังช่วยให้การบริหารจัดการทรัพยากรมีประสิทธิภาพมากขึ้น เช่น การจัดสรรคนขับและจำนวนรถที่ตรงกับความต้องการของลูกค้า
# ในแต่ละช่วงเวลา
#
# #### ข้อคาดการณ์ของท่านจะนำไปสู่การแก้ไขปัญหาหรือตอบคำถาม
# 1. ค่าทางด่วน (tolls_amount) มีส่งผลให้จำนวนทิปจากผู้โดยสารมากขึ้น
# 2. อากาศที่ร้อนมีผลต่อการให้ทิปของผู้โดยสาร
# 3. ผู้โดยสารอาจมีแนวโน้มให้ทิปมากขึ้นในวันหยุดสุดสัปดาห์

# %%
# Descriptive statistics

# Data visualization
# Target variable analysis: examine how each feature correlates with or impacts the target/interested variable

# %% [markdown]
# ### Library Loading

# %%
# !pip install contextily geopy mercantile

# %%
import pandas as pd
import pyarrow.parquet as pq
import numpy as np
import os
from pandas.tseries.holiday import USFederalHolidayCalendar as calander
import warnings
import geopandas as gpd
import zipfile
import contextily as ctx

warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", 30)
color = sns.color_palette("tab10")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset Loading

# %% [markdown]
# #### Trips_2023

# %%
# Path to the zip file and .shp file inside
zip_path = '/content/drive/MyDrive/Bigdata/taxi_zones.zip'
shapefile_name = 'taxi_zones.shp'  # Name of the .shp file inside the zip

# Open the zip file and read the .shp file directly
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/shapefile_extracted')  # Extract to a temp folder

# Path to the extracted .shp file
shapefile_path = '/content/shapefile_extracted/' + shapefile_name

# Read the shapefile using geopandas
gdf = gpd.read_file(shapefile_path)

# Convert GeoDataFrame to a regular pandas DataFrame (if you don't need geometry)
df = pd.DataFrame(gdf.drop(columns='geometry'))  # Drop the 'geometry' column if not needed

# Display the DataFrame
print(df.head())
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough
# 0            EWR
# 1         Queens
# 2          Bronx
# 3      Manhattan
# 4  Staten Island

# %%
# Set the config option to restore .shx file
os.environ['SHAPE_RESTORE_SHX'] = 'YES'

# Try reading the file again
shapefile_path = '/content/drive/MyDrive/Bigdata/taxi_zones.shp'
taxi_zones = gpd.read_file(shapefile_path)

# %%
# Merge both DataFrames on their index
merged_df = pd.concat([df, taxi_zones], axis=1)

# Display the merged DataFrame
merged_df
# Out:
#      OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0           1    0.116357    0.000782           Newark Airport           1
# 1           2    0.433470    0.004866              Jamaica Bay           2
# 2           3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3           4    0.043567    0.000112            Alphabet City           4
# 4           5    0.092146    0.000498            Arden Heights           5
# ..        ...         ...         ...                      ...         ...
# 258       259    0.126750    0.000395       Woodlawn/Wakefield         259
# 259       260    0.133514    0.000422                 Woodside         260
# 260       261    0.027120    0.000034       World Trade Center         261
# 261       262    0.049064    0.000122           Yorkville East         262
# 262       263    0.037017    0.000066           Yorkville West         263
#
# ...

# %%
# Read the CSV files
winter_data = pd.read_csv('/content/drive/MyDrive/Bigdata/taxi_data_processed1.csv')
summer_data = pd.read_csv('/content/drive/MyDrive/Bigdata/taxi_data_processed7.csv')

'''
# Concatenate the winter and summer data into separate DataFrames
winter_data = pd.concat([winter_data1, winter_data2], ignore_index=True)
summer_data = pd.concat([summer_data7, summer_data8], ignore_index=True)
'''
# Optionally, you can add a column to differentiate between winter and summer data
winter_data['season'] = 'winter'
summer_data['season'] = 'summer'

# Combine winter and summer data if needed
# all_data = pd.concat([winter_data, summer_data], ignore_index=True)

# Now you have separate DataFrames (winter_data and summer_data)
# or a combined DataFrame (all_data) for your analysis.

# %%
summer_data
# Out:
#          VendorID passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0               1           small           1.80         1.0           140
# 1               2           small           2.31         1.0           163
# 2               2           small           2.36         1.0           142
# 3               2           small           4.36         1.0            68
# 4               2           small           8.67         1.0           138
# ...           ...             ...            ...         ...           ...
# 2635195         1          medium           2.70         1.0           234
# 2635196         1           small          10.50         1.0            50
# 2635197         2           small           3.62         1.0            48
# 2635198         2           small           1.23         1.0            48
# 2635199         2           small          21.02         2.0           132
#
# ...

# %%
# Combine winter and summer data if needed
all_data = pd.concat([winter_data, summer_data], ignore_index=True)
all_data
# Out:
#          VendorID passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0               2           small           0.97         1.0           161
# 1               2           small           1.10         1.0            43
# 2               2           small           2.51         1.0            48
# 3               2           small           1.43         1.0           107
# 4               2           small           1.84         1.0           161
# ...           ...             ...            ...         ...           ...
# 5438671         1          medium           2.70         1.0           234
# 5438672         1           small          10.50         1.0            50
# 5438673         2           small           3.62         1.0            48
# 5438674         2           small           1.23         1.0            48
# 5438675         2           small          21.02         2.0           132
#
# ...

# %%
all_data.columns
# Out:
# Index(['VendorID', 'passenger_count', 'trip_distance', 'RatecodeID',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount',
#        'tip_amount', 'tolls_amount', 'total_amount', 'congestion_surcharge',
#        'airport_fee', 'date', 'time', 'weekday', 'duration', 'day_type',
#        'tip_percent', 'time_desc', 'avg_temp', 'precip', 'windspeed', 'snow',
#        'snowdepth', 'PUborough', 'DOborough', 'season', 'Airport_fee'],
#       dtype='object')

# %%
# Compute pickup and dropoff amount of each zone
pu_zone = all_data.groupby(['PULocationID'], as_index=False).size()
do_zone = all_data.groupby(['DOLocationID'], as_index=False).size()

# %%
pu_zone
# Out:
#      PULocationID    size
# 0               1     141
# 1               2       5
# 2               3      91
# 3               4    5605
# 4               5      64
# ..            ...     ...
# 251           259     121
# 252           260     995
# 253           261   28039
# 254           262   70316
# 255           263  108450
#
# [256 rows x 2 columns]

# %%
merged_df
# Out:
#      OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0           1    0.116357    0.000782           Newark Airport           1
# 1           2    0.433470    0.004866              Jamaica Bay           2
# 2           3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3           4    0.043567    0.000112            Alphabet City           4
# 4           5    0.092146    0.000498            Arden Heights           5
# ..        ...         ...         ...                      ...         ...
# 258       259    0.126750    0.000395       Woodlawn/Wakefield         259
# 259       260    0.133514    0.000422                 Woodside         260
# 260       261    0.027120    0.000034       World Trade Center         261
# 261       262    0.049064    0.000122           Yorkville East         262
# 262       263    0.037017    0.000066           Yorkville West         263
#
# ...

# %%
# ตรวจสอบว่า zone_gdf อยู่ในรูปแบบ GeoDataFrame ไม่ใช่ DataFrame ธรรมดา
pu_zone_gdf = gpd.GeoDataFrame(merged_df, geometry='geometry')
do_zone_gdf = gpd.GeoDataFrame(merged_df, geometry='geometry')

# ตั้งค่า CRS เริ่มต้นสำหรับ GeoDataFrame
pu_zone_gdf = pu_zone_gdf.set_crs(epsg=4326)
do_zone_gdf = do_zone_gdf.set_crs(epsg=4326)

# จากนั้นแปลงพิกัดไปยัง EPSG:3857
pu_zone_gdf = pu_zone_gdf.to_crs(epsg=3857)
do_zone_gdf = do_zone_gdf.to_crs(epsg=3857)

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import numpy as np

# Compute pickup and dropoff counts
def create_spatial_visualization(all_data, taxi_zones_gdf):
    """
    Create spatial visualization of pickup and dropoff patterns

    Parameters:
    -----------
    all_data : pandas DataFrame
        Combined taxi trip data
    taxi_zones_gdf : GeoDataFrame
        Taxi zones with geometry information
    """
    # Compute counts for each zone
    pu_counts = all_data['PULocationID'].value_counts().reset_index()
    pu_counts.columns = ['LocationID', 'pickup_count']

    do_counts = all_data['DOLocationID'].value_counts().reset_index()
    do_counts.columns = ['LocationID', 'dropoff_count']

    # Create GeoDataFrames with counts
    pu_zone_gdf = taxi_zones_gdf.merge(pu_counts, on='LocationID', how='left')
    do_zone_gdf = taxi_zones_gdf.merge(do_counts, on='LocationID', how='left')

    # Fill NaN values with 0
    pu_zone_gdf['pickup_count'] = pu_zone_gdf['pickup_count'].fillna(0)
    do_zone_gdf['dropoff_count'] = do_zone_gdf['dropoff_count'].fillna(0)

    # Convert to EPSG:3857 for web mercator projection
    pu_zone_gdf = pu_zone_gdf.to_crs(epsg=3857)
    do_zone_gdf = do_zone_gdf.to_crs(epsg=3857)

    # Create visualization
    fig, axs = plt.subplots(ncols=2, figsize=(20, 10))
    fig.subplots_adjust(bottom=0.1, top=0.9, left=0.09, right=0.8, wspace=0.02, hspace=0.02)

    # Plot pickup patterns
    pu_plot = pu_zone_gdf.plot(column='pickup_count',
                              ax=axs[0],
                              cmap='Blues',
                              legend=False,
                              linewidth=0.09)

    # Plot dropoff patterns
    do_plot = do_zone_gdf.plot(column='dropoff_count',
                              ax=axs[1],
                              cmap='Blues',
                              legend=False,
                              linewidth=0.09)

    # Add basemaps
    ctx.add_basemap(axs[0], crs=pu_zone_gdf.crs.to_string())
    ctx.add_basemap(axs[1], crs=do_zone_gdf.crs.to_string())

    # Set titles
    axs[0].set_title('Pickup Patterns')
    axs[1].set_title('Dropoff Patterns')

    # Remove axes
    axs[0].set_axis_off()
    axs[1].set_axis_off()

    # Add colorbar
    norm = plt.Normalize(vmin=min(pu_zone_gdf['pickup_count'].min(),
                                do_zone_gdf['dropoff_count'].min()),
                        vmax=max(pu_zone_gdf['pickup_count'].max(),
                                do_zone_gdf['dropoff_count'].max()))

    sm = plt.cm.ScalarMappable(cmap='Blues', norm=norm)
    cb = fig.colorbar(sm, ax=axs, shrink=0.72, orientation="vertical", pad=0.005)
    cb.ax.set_ylabel('Trip Count')

    plt.show()

    return pu_zone_gdf, do_zone_gdf

# %%
# Example usage
if __name__ == "__main__":
    # Read the shapefile
    taxi_zones = gpd.read_file('/content/shapefile_extracted/taxi_zones.shp')
    taxi_zones = taxi_zones.to_crs(epsg=4326)  # Ensure it's in WGS84

    # Create visualization
    pu_zone_gdf, do_zone_gdf = create_spatial_visualization(summer_data, taxi_zones)

    # Print top 5 pickup and dropoff zones
    print("\nTop 5 Pickup Zones:")
    print(pu_zone_gdf.nlargest(5, 'pickup_count')[['zone', 'pickup_count']])

    print("\nTop 5 Dropoff Zones:")
    print(do_zone_gdf.nlargest(5, 'dropoff_count')[['zone', 'dropoff_count']])
# Out:
# Top 5 Pickup Zones:
#                              zone  pickup_count
# 131                   JFK Airport      156416.0
# 160                Midtown Center      128407.0
# 236         Upper East Side South      112798.0
# 185  Penn Station/Madison Sq West      100778.0
# 161                  Midtown East       99749.0
#
# Top 5 Dropoff Zones:
#                           zone  dropoff_count
# 160             Midtown Center       107636.0
# 235      Upper East Side North       100458.0
# 236      Upper East Side South        99302.0
# 229  Times Sq/Theatre District        90319.0
# 169                Murray Hill        83660.0

# %%
winter_data
# Out:
#          VendorID passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0               2           small           0.97         1.0           161
# 1               2           small           1.10         1.0            43
# 2               2           small           2.51         1.0            48
# 3               2           small           1.43         1.0           107
# 4               2           small           1.84         1.0           161
# ...           ...             ...            ...         ...           ...
# 2803471         1           small          13.90        99.0           228
# 2803472         2           small           3.37         1.0           263
# 2803473         2           small           2.86         1.0            79
# 2803474         1           small           3.80         1.0            68
# 2803475         2           small           0.60         1.0           236
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming yellow_winter and yellow_summer DataFrames are already prepared
cats = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Compute the number of pickups at each hour throughout the week
winter_pu_count = pd.crosstab(winter_data['weekday'], winter_data['time']).reindex(cats, axis=0)
summer_pu_count = pd.crosstab(summer_data['weekday'], summer_data                                              ['time']).reindex(cats, axis=0)

# Determine max value for dynamic color limits
vmax = max(winter_pu_count.max().max(), summer_pu_count.max().max())

# Create subplots for heatmaps
fig, (ax, ax2) = plt.subplots(ncols=2, figsize=(20, 10))
fig.subplots_adjust(wspace=0.005)

# Winter heatmap
day_hour_winter = sns.heatmap(winter_pu_count.transpose(), ax=ax, cmap="coolwarm", vmax=vmax, cbar=False)
fig.colorbar(ax.collections[0], label='Number of trips', ax=ax, location="left", use_gridspec=False, pad=0.07)
day_hour_winter.invert_yaxis()
ax.set_title('Winter')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Hour of the Day')

# Summer heatmap
day_hour_summer = sns.heatmap(summer_pu_count.transpose(), ax=ax2, cmap="coolwarm", vmax=vmax, cbar=False)
fig.colorbar(ax2.collections[0], label='Number of trips', ax=ax2, location="right", use_gridspec=False, pad=0.07)
day_hour_summer.invert_yaxis()
ax2.set_title('Summer')
ax2.set_xlabel('Day of the Week')
ax2.set_ylabel('Hour of the Day')
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()
ax2.tick_params(rotation=0)

# Show the plot
plt.show()

# %%
# Create the stacked data for winter pickups
wt = pd.crosstab(winter_data['weekday'], winter_data['time_desc']).reindex(cats, axis=0)
stacked_winter = wt.stack().reset_index().rename(columns={0:'pick_ups'})

# Define the correct order for time description
time_order = ['Late Night', 'Morning', 'Afternoon', 'Evening']
stacked_winter['time_desc'] = pd.Categorical(stacked_winter['time_desc'], categories=time_order)

# Plotting the barplot
fig, ax = plt.subplots(figsize=(7, 4))
sns.barplot(x=stacked_winter['weekday'], y=stacked_winter['pick_ups'], hue=stacked_winter['time_desc'], ax=ax, palette='muted')

# Set plot labels and title
ax.set_ylabel('Number of Taxi Trips')
ax.set_xlabel('Day of the week')
ax.set_title('Taxi pickups at different times across the weekdays (Winter)')

# Adjust Y-axis formatting
plt.ticklabel_format(style='plain', axis='y')
plt.ylim(0, stacked_winter['pick_ups'].max() * 1.1)  # Adjust dynamically based on max pickups

# Customize the legend
plt.legend(loc='upper right', ncol=len(time_order), prop={'size': 10.5})

# Show the plot
plt.show()

# %%
# Create the stacked data for winter pickups
wt = pd.crosstab(summer_data['weekday'], summer_data['time_desc']).reindex(cats, axis=0)
stacked_winter = wt.stack().reset_index().rename(columns={0:'pick_ups'})

# Define the correct order for time description
time_order = ['Late Night', 'Morning', 'Afternoon', 'Evening']
stacked_winter['time_desc'] = pd.Categorical(stacked_winter['time_desc'], categories=time_order)

# Plotting the barplot
fig, ax = plt.subplots(figsize=(7, 4))
sns.barplot(x=stacked_winter['weekday'], y=stacked_winter['pick_ups'], hue=stacked_winter['time_desc'], ax=ax, palette='muted')

# Set plot labels and title
ax.set_ylabel('Number of Taxi Trips')
ax.set_xlabel('Day of the week')
ax.set_title('Taxi pickups at different times across the weekdays (Summer)')

# Adjust Y-axis formatting
plt.ticklabel_format(style='plain', axis='y')
plt.ylim(0, stacked_winter['pick_ups'].max() * 1.1)  # Adjust dynamically based on max pickups

# Customize the legend
plt.legend(loc='upper right', ncol=len(time_order), prop={'size': 10.5})

# Show the plot
plt.show()

# %%
# Filter payment types to exclude cash payments (payment_type != 2)
tip = all_data[all_data['payment_type'] != 2]

# Compute the mean tipping percentage grouped by weekday and hour
tip_percent = tip.groupby(['weekday', 'time'], as_index=False)['tip_percent'].mean()

# Ensure proper weekday order
tip_percent.weekday = pd.Categorical(tip_percent.weekday, categories=cats)
tip_percent = tip_percent.sort_values(['weekday', 'time']).reset_index(drop=True)

# Create pivot table for heatmap
tip_percent_heatmap = pd.pivot_table(tip_percent, values='tip_percent', index='weekday', columns='time')

# Plot the heatmap
fig, ax = plt.subplots(figsize=(13, 3.5))
sns.heatmap(tip_percent_heatmap, cbar_kws={'label': 'Tip Percentage'}, ax=ax, cmap='coolwarm')

# Set labels and title
ax.set_ylabel('Weekday')
ax.set_xlabel('Hour of the day')
ax.set_title('Tipping Percent Throughout Different Times of the Week')

# Display the plot
plt.show()

# %%
do_tip = tip.groupby(['DOLocationID'], as_index=False)['tip_amount'].mean()
do_gdf = gpd.GeoDataFrame(pd.merge(do_tip, merged_df, left_on='DOLocationID', right_on='LocationID')).drop('DOLocationID',axis=1)

# %%
# idenitify missing taxi zone
missing_list = list(set(merged_df['OBJECTID']) - set(do_gdf['OBJECTID']))
missing = merged_df[merged_df['OBJECTID'].isin(missing_list)]
missing.insert(0, 'tip_amount', np.nan, True)
missing = missing.drop('LocationID', axis=1)
# Use the existing index from do_gdf after concatenation
do_gdf = pd.concat([do_gdf, missing], ignore_index=True).drop('LocationID', axis=1, errors='ignore')
# Rename the 'OBJECTID' column to 'LocationID'
do_gdf = do_gdf.rename({'OBJECTID':'LocationID'}, axis=1)
do_gdf = do_gdf.set_crs(epsg=4326)

do_gdf = do_gdf.to_crs(epsg=3857)

# %%
pu_tip = tip.groupby(['PULocationID'], as_index=False)['tip_amount'].mean()
pu_gdf = gpd.GeoDataFrame(pd.merge(pu_tip, merged_df, left_on='PULocationID', right_on='LocationID')).drop('PULocationID',axis=1)

# idenitify missing taxi zone
missing_list = list(set(merged_df['OBJECTID']) - set(pu_gdf['OBJECTID']))
missing = merged_df[merged_df['OBJECTID'].isin(missing_list)]
missing.insert(0, 'tip_amount', np.nan, True)
missing = missing.drop('LocationID', axis=1)
pu_gdf = pd.concat([pu_gdf, missing]).reset_index().drop('LocationID', axis=1)
pu_gdf = pu_gdf.rename({'OBJECTID':'LocationID'}, axis=1)

# %%
pu_gdf = pu_gdf.set_crs(epsg=4326)
pu_gdf = pu_gdf.to_crs(epsg=3857)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(20, 10))
vmin, vmax = pu_gdf['tip_amount'].min(), pu_gdf['tip_amount'].max()
pu_gdf.plot(column='tip_amount', cmap='Spectral_r', linewidth=0.05, ax=axs[0], edgecolor='k',
    legend=True, legend_kwds={'label': "Average Tip Amount", 'shrink': 0.78}, vmin=vmin, vmax=vmax,
    missing_kwds={"color": "lightgrey", "edgecolor": "red", "hatch": "///", "label": "Missing values"})

vmin, vmax = do_gdf['tip_amount'].min(), do_gdf['tip_amount'].max()
do_gdf.plot(column='tip_amount', cmap='Spectral_r', linewidth=0.05, ax=axs[1], edgecolor='k',
    legend=True, legend_kwds={'label': "Average Tip Amount", 'shrink': 0.78}, vmin=vmin, vmax=vmax,
    missing_kwds={"color": "lightgrey", "edgecolor": "red", "hatch": "///", "label": "Missing values"})

fig.subplots_adjust(wspace=0)
ctx.add_basemap(axs[0])
ctx.add_basemap(axs[1])
axs[0].set_axis_off()
axs[1].set_axis_off()
axs[0].set_title("Average Tips per Trip by Pickup Zones")
axs[1].set_title("Average Tips per Trip by Dropoff Zones")
plt.show()

# %%
# identify top 10 zone with highest average tips
top_10 = pd.merge(do_gdf, tip['DOLocationID'].value_counts().sort_index(), left_on='LocationID', right_on=tip['DOLocationID'].value_counts().sort_index().index)
top_10 = top_10.rename({'LocationID': 'Pickup_freq'}, axis=1)

# %%
top_10 = top_10[top_10['Pickup_freq'] > 100]
top_10 = top_10.sort_values('tip_amount', ascending=False)[:10]

fig, ax = plt.subplots(figsize=(10, 2))
ax.bar(top_10['zone'], top_10['tip_amount'])
ax.set_xlabel('Zone Name')
ax.set_ylabel('Avg tips per trip ($)')
plt.xticks(rotation=15,horizontalalignment="right")
plt.show()

# %% [markdown]
# ## How does weather affect the usage of taxi?

# %%
winter_data
# Out:
#          VendorID passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0               2           small           0.97         1.0           161
# 1               2           small           1.10         1.0            43
# 2               2           small           2.51         1.0            48
# 3               2           small           1.43         1.0           107
# 4               2           small           1.84         1.0           161
# ...           ...             ...            ...         ...           ...
# 2803471         1           small          13.90        99.0           228
# 2803472         2           small           3.37         1.0           263
# 2803473         2           small           2.86         1.0            79
# 2803474         1           small           3.80         1.0            68
# 2803475         2           small           0.60         1.0           236
#
# ...

# %%
# Group and count trip based on date and weather condition

winter_prcp = pd.DataFrame(winter_data.groupby(['date', 'precip']).size()).reset_index()
summer_prcp = pd.DataFrame(summer_data.groupby(['date', 'precip']).size()).reset_index()
winter_prcp.columns = ['date', 'precip', 'pickup_freq']
summer_prcp.columns = ['date', 'precip', 'pickup_freq']

winter_awnd = pd.DataFrame(winter_data.groupby(['date', 'windspeed']).size()).reset_index()
summer_awnd = pd.DataFrame(summer_data.groupby(['date', 'windspeed']).size()).reset_index()
winter_awnd.columns = ['date', 'windspeed', 'pickup_freq']
summer_awnd.columns = ['date', 'windspeed', 'pickup_freq']

winter_snow = pd.DataFrame(winter_data.groupby(['date', 'snow']).size()).reset_index()
summer_snow = pd.DataFrame(summer_data.groupby(['date', 'snow']).size()).reset_index()
winter_snow.columns = ['date', 'snow', 'pickup_freq']
summer_snow.columns = ['date', 'snow', 'pickup_freq']

winter_snwd = pd.DataFrame(winter_data.groupby(['date', 'snowdepth']).size()).reset_index()
summer_snwd = pd.DataFrame(summer_data.groupby(['date', 'snowdepth']).size()).reset_index()
winter_snwd.columns = ['date', 'snowdepth', 'pickup_freq']
summer_snwd.columns = ['date', 'snowdepth', 'pickup_freq']

# %%
# First define the helper function for safe polynomial fitting
def safe_polyfit(x, y):
    """Safely perform polynomial fitting with error handling"""
    try:
        # Remove any NaN values
        mask = ~(np.isnan(x) | np.isnan(y))
        x_clean = x[mask]
        y_clean = y[mask]

        # Check if we have enough data points
        if len(x_clean) < 2:
            return None, None

        # Perform the polynomial fit
        z = np.polyfit(x_clean, y_clean, 1)
        p = np.poly1d(z)
        return z, p
    except Exception as e:
        print(f"Error in polynomial fitting: {e}")
        return None, None

# Create the plot
fig, axs = plt.subplots(2, 2, figsize=(12, 10), sharey=True)

# Precipitation subplot (top left)
for data, season, color in [(winter_prcp, 'Winter', 'b'), (summer_prcp, 'Summer', 'r')]:
    z, p = safe_polyfit(data['precip'], data['pickup_freq'])
    if p is not None:
        axs[0, 0].plot(data['precip'], p(data['precip']), c=color)
    axs[0, 0].scatter(data['precip'], data['pickup_freq'], c=color, label=season, alpha=0.5)
axs[0, 0].set_xlabel('Precipitation (inches)')
axs[0, 0].set_ylabel('Number of pickups')
axs[0, 0].set_title('Precipitation Effect')
axs[0, 0].grid(True, alpha=0.3)

# Wind speed subplot (top right)
for data, season, color in [(winter_awnd, 'Winter', 'b'), (summer_awnd, 'Summer', 'r')]:
    z, p = safe_polyfit(data['windspeed'], data['pickup_freq'])
    if p is not None:
        axs[0, 1].plot(data['windspeed'], p(data['windspeed']), c=color)
    axs[0, 1].scatter(data['windspeed'], data['pickup_freq'], c=color, label=season, alpha=0.5)
axs[0, 1].set_xlabel('Avg. Daily Wind Speed (mph)')
axs[0, 1].set_title('Wind Speed Effect')
axs[0, 1].grid(True, alpha=0.3)

# Snow subplot (bottom left)
z, p = safe_polyfit(winter_snow['snow'], winter_snow['pickup_freq'])
if p is not None:
    axs[1, 0].plot(winter_snow['snow'], p(winter_snow['snow']), c='b')
axs[1, 0].scatter(winter_snow['snow'], winter_snow['pickup_freq'], c='b', label='Winter', alpha=0.5)
axs[1, 0].set_xlabel('Snow (inches)')
axs[1, 0].set_ylabel('Number of pickups')
axs[1, 0].set_title('Snow Effect')
axs[1, 0].grid(True, alpha=0.3)

# Snow depth subplot (bottom right)
z, p = safe_polyfit(winter_snwd['snowdepth'], winter_snwd['pickup_freq'])
if p is not None:
    axs[1, 1].plot(winter_snwd['snowdepth'], p(winter_snwd['snowdepth']), c='b')
axs[1, 1].scatter(winter_snwd['snowdepth'], winter_snwd['pickup_freq'], c='b', label='Winter', alpha=0.5)
axs[1, 1].set_xlabel('Snow Depth (inches)')
axs[1, 1].set_title('Snow Depth Effect')
axs[1, 1].grid(True, alpha=0.3)

# Add legend to the first subplot
axs[0, 0].legend(loc='lower right')

# Add main title
plt.suptitle('Weather Conditions vs Pickup Frequency by Day', fontsize=14, y=1.02)

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# Error in polynomial fitting: SVD did not converge in Linear Least Squares

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# ![Datadict taxi.png](data:image/png;base64,...)

# %%
all_data
# Out:
#          VendorID passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0               2           small           0.97         1.0           161
# 1               2           small           1.10         1.0            43
# 2               2           small           2.51         1.0            48
# 3               2           small           1.43         1.0           107
# 4               2           small           1.84         1.0           161
# ...           ...             ...            ...         ...           ...
# 5438671         1          medium           2.70         1.0           234
# 5438672         1           small          10.50         1.0            50
# 5438673         2           small           3.62         1.0            48
# 5438674         2           small           1.23         1.0            48
# 5438675         2           small          21.02         2.0           132
#
# ...

# %% [markdown]
# #### สรุปผลที่ได้
# จากการวิเคราะห์ข้อมูลแท็กซี่สีเหลือง จะเห็นว่าปัจจัยสำคัญที่ส่งผลต่อการให้ทิป ได้แก่ ระยะทาง, ค่าโดยสาร, และยอดสุทธิ ในขณะที่สภาพอากาศมีผลกระทบเพียงเล็กน้อย
# นอกจากนี้ ยังพบว่าผู้โดยสารมักใช้บริการแท็กซี่มากขึ้นในช่วงฤดูร้อนเมื่อเทียบกับฤดูหนาว โดยเฉพาะในวันธรรมดาช่วงเย็นซึ่งตรงกับเวลาเลิกงาน แม้โซนที่มีการให้ทิปสูงจะไม่ใช่โซนที่มีการรับ-ส่งผู้โดยสารมากที่สุดเสมอไป ซึ่งอาจสะท้อนพฤติกรรมการให้ทิปที่แตกต่างกันในแต่ละพื้นที่ ในส่วนของการทำนายจำนวนทิป โมเดล **Gradient Boosting Regressor (GBR)** ให้ผลลัพธ์ที่ดีที่สุด แม้ว่าจะยังมีจุดที่ต้องปรับปรุง แต่ก็มีโอกาสในการพัฒนาโมเดลให้แม่นยำมากขึ้นหากมีข้อมูลสภาพอากาศที่ละเอียดขึ้นในอนาคต
#
# นอกจากนี้ การวิเคราะห์ข้อมูลสามารถปรับปรุงบริการแท็กซี่ได้ เช่น การเพิ่มขึ้นของจำนวนผู้โดยสารในช่วงฤดูร้อนเมื่อมีฝนตก และผลกระทบเชิงลบจากหิมะที่ทำให้จำนวนผู้โดยสารลดลง เราสามารถใช้ข้อมูลเหล่านี้ในการวางแผนการให้บริการ เช่น การจัดสรรจำนวนรถและคนขับ
# ในช่วงที่มีฝนตกหรือหิมะตกเพื่อให้บริการได้อย่างมีประสิทธิภาพ

# %% [markdown]
# -----------------
# # เสร็จแล้ววววว 🥳
#
# สิ่งที่ต้องแนบส่ง:
# * Notebook File (ตัวอย่าง "filename.ipynb") หรือ Link to Google Colab / GitHub ซึ่งมีผลลัพธ์จากการรันโค้ดแสดงทั้งหมด
# * Slides สำหรับการนำเสนอ **10** นาที ซึ่งประกอบไปด้วย
#     * Data Description: อธิบายข้อมูลที่ใช้
#     * Data Preparation: การเตรียมข้อมูลก่อนวิเคราะห์
#     * Motivation: ปัญหาหรือคำถามที่ตั้ง ทำไมถึงสนใจที่จะทำงานในเรื่องนี้
#     * Communicating Results (with figure, table, etc.): ผลที่ได้จากการศึกษา โดยระบุแนวทางที่ใช้ที่ทำให้เกิดผลลัพธ์ดังกล่าวด้วย
#         โดยไม่ต้องนำเสนอ source code ผลประกอบด้วย 2 ส่วนสำคัญ จาก
#         * Conjectures >= 3 ข้อ
#         * Machine learning models
#     * Conclusion: สรุปผลที่ได้จากการวิเคราะห์ข้อมูล
# ** Note: แต่ละกลุ่มส่งแต่ละไฟล์ครั้งเดียว **
# ---------------------
